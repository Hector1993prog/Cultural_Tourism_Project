# %%
import os
from functions import *

# %%
import codecs
import json
import csv
import re
import os

files = []
for file in os.listdir(r"C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\CULTURAL VIEWER FINAL PROJECT\json"):
    if file.endswith(".json"):
        files.append(os.path.join(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\CULTURAL VIEWER FINAL PROJECT\json', file))

for file in files:
    with codecs.open(file) as f: 
        tweets = json.load(f)
len(files)
# Out:
# 100

# %%
# !pip install natsort
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from natsort import natsorted 
files1= natsorted(files)
files1
# Out:
# ['C:\\Users\\Héctor\\Documents\\IRONHACK\\DATA ANALIST\\BOOTCAMP\\CULTURAL VIEWER FINAL PROJECT\\json\\1. Mezquita Azul.json',
#  'C:\\Users\\Héctor\\Documents\\IRONHACK\\DATA ANALIST\\BOOTCAMP\\CULTURAL VIEWER FINAL PROJECT\\json\\2. Gran_bazar.json',
#  'C:\\Users\\Héctor\\Documents\\IRONHACK\\DATA ANALIST\\BOOTCAMP\\CULTURAL VIEWER FINAL PROJECT\\json\\3. bazar_de_las_especias.json',
#  'C:\\Users\\Héctor\\Documents\\IRONHACK\\DATA ANALIST\\BOOTCAMP\\CULTURAL VIEWER FINAL PROJECT\\json\\4. mez_de_suleiman.json',
#  'C:\\Users\\Héctor\\Documents\\IRONHACK\\DATA ANALIST\\BOOTCAMP\\CULTURAL VIEWER FINAL PROJECT\\json\\5. hipodromo_constantinopla.json',
#  'C:\\Users\\Héctor\\Documents\\IRONHACK\\DATA ANALIST\\BOOTCAMP\\CULTURAL VIEWER FINAL PROJECT\\json\\6. puente_gatala.json',
#  'C:\\Users\\Héctor\\Documents\\IRONHACK\\DATA ANALIST\\BOOTCAMP\\CULTURAL VIEWER FINAL PROJECT\\json\\7. parque_gülhane.json',
# ...

# %%
data= list(map(clean_count_2,files1))
# Out:
# {'places': 20, 'cafe': 20, 'bar': 2, 'spa': 1, 'lodging': 1, 'restaurant': 11, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 7, 'night_club': 1, 'book_store': 1}
# {'places': 20, 'cafe': 20, 'bar': 2, 'restaurant': 9, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'store': 3, 'bakery': 1, 'night_club': 1}
# {'places': 20, 'cafe': 20, 'spa': 1, 'lodging': 1, 'bar': 2, 'restaurant': 10, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 6, 'bakery': 2}
# {'places': 20, 'cafe': 20, 'bar': 1, 'restaurant': 8, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 3, 'bakery': 1}
# {'places': 20, 'bar': 2, 'cafe': 20, 'spa': 1, 'lodging': 1, 'restaurant': 11, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 7, 'night_club': 1, 'book_store': 1}
# ...

# %%
lst9=[{'places': 20, 'cafe': 20, 'bar': 2, 'spa': 1, 'lodging': 1, 'restaurant': 11, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 7, 'night_club': 1, 'book_store': 1},
{'places': 20, 'cafe': 20, 'bar': 2, 'restaurant': 9, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'store': 3, 'bakery': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'spa': 1, 'lodging': 1, 'bar': 2, 'restaurant': 10, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 6, 'bakery': 2},
{'places': 20, 'cafe': 20, 'bar': 1, 'restaurant': 8, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 3, 'bakery': 1},
{'places': 20, 'bar': 2, 'cafe': 20, 'spa': 1, 'lodging': 1, 'restaurant': 11, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 7, 'night_club': 1, 'book_store': 1},
{'places': 20, 'spa': 1, 'cafe': 20, 'bar': 3, 'lodging': 2, 'restaurant': 10, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 5, 'bakery': 1},
{'places': 20, 'cafe': 20, 'spa': 1, 'bar': 2, 'lodging': 1, 'restaurant': 14, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'bakery': 3, 'store': 8},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 6, 'bakery': 1, 'store': 3},
{'places': 20, 'tourist_attraction': 1, 'cafe': 20, 'lodging': 1, 'restaurant': 5, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'store': 3, 'night_club': 1, 'bar': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 9, 'florist': 1, 'store': 5, 'liquor_store': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 9, 'florist': 1, 'store': 5, 'liquor_store': 1},
{'places': 20, 'restaurant': 6, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bar': 1, 'store': 7, 'bakery': 4},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 2, 'restaurant': 6, 'store': 5},
{'places': 20, 'restaurant': 9, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bar': 2, 'store': 5, 'bakery': 1, 'book_store': 1, 'movie_rental': 1, 'electronics_store': 1, 'home_goods_store': 1},
{'places': 20, 'bar': 2, 'cafe': 20, 'spa': 1, 'lodging': 1, 'restaurant': 10, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 2, 'store': 6},
{'places': 20, 'cafe': 20, 'store': 10, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 4, 'bakery': 1},
{'places': 20, 'cafe': 20, 'lodging': 3, 'store': 2, 'restaurant': 9, 'food': 20, 'bar': 7, 'point_of_interest': 20, 'establishment': 20, 'movie_theater': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'restaurant': 6, 'store': 4},
{'places': 20, 'cafe': 20, 'bar': 2, 'restaurant': 8, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 3, 'bakery': 1, 'night_club': 1},
{'places': 20, 'restaurant': 8, 'cafe': 20, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'bar': 1, 'store': 7, 'bakery': 3},
{'places': 20, 'spa': 1, 'cafe': 20, 'bar': 2, 'lodging': 1, 'restaurant': 10, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 5, 'bakery': 2},
{'places': 20, 'cafe': 20, 'bar': 7, 'lodging': 4, 'restaurant': 10, 'food': 20, 'store': 3, 'point_of_interest': 20, 'establishment': 20, 'gym': 1, 'health': 1, 'movie_theater': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'bar': 2, 'spa': 1, 'lodging': 1, 'restaurant': 13, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 4, 'store': 9},
{'places': 20, 'cafe': 20, 'lodging': 4, 'restaurant': 5, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'gym': 1, 'health': 1, 'spa': 1, 'parking': 1, 'movie_theater': 1, 'night_club': 1, 'bar': 4, 'store': 3},
{'places': 20, 'cafe': 20, 'restaurant': 8, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'gas_station': 1, 'car_wash': 1, 'convenience_store': 1, 'bakery': 2, 'car_repair': 1, 'store': 5, 'bar': 1},
{'places': 20, 'cafe': 20, 'bar': 3, 'restaurant': 12, 'food': 20, 'spa': 1, 'lodging': 1, 'point_of_interest': 20, 'establishment': 20, 'bakery': 4, 'store': 8, 'book_store': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'lodging': 5, 'restaurant': 10, 'bar': 7, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'store': 2, 'gym': 1, 'health': 1, 'parking': 1, 'spa': 1, 'movie_theater': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'gym': 1, 'lodging': 2, 'restaurant': 6, 'food': 20, 'health': 1, 'point_of_interest': 20, 'establishment': 20, 'parking': 1, 'spa': 1, 'store': 9, 'bakery': 2, 'art_gallery': 1, 'bar': 1},
{'places': 20, 'bakery': 2, 'cafe': 20, 'restaurant': 12, 'food': 20, 'point_of_interest': 20, 'store': 6, 'establishment': 20, 'book_store': 1, 'night_club': 1, 'bar': 3, 'art_gallery': 1},
{'places': 20, 'cafe': 20, 'store': 8, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'restaurant': 4},
{'places': 20, 'cafe': 20, 'store': 5, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 1},
{'places': 20, 'cafe': 20, 'spa': 1, 'bar': 2, 'lodging': 1, 'restaurant': 11, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'bakery': 3, 'store': 7, 'book_store': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'restaurant': 7, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'gas_station': 1, 'convenience_store': 1, 'car_wash': 1, 'bakery': 2, 'car_repair': 1, 'store': 6, 'bar': 1},
{'places': 20, 'cafe': 20, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'restaurant': 2, 'store': 6},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 3, 'store': 8, 'home_goods_store': 1, 'bakery': 2},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 2, 'store': 8, 'home_goods_store': 1},
{'places': 20, 'restaurant': 8, 'cafe': 20, 'bar': 1, 'point_of_interest': 20, 'food': 20, 'store': 6, 'establishment': 20, 'bakery': 3},
{'places': 20, 'restaurant': 8, 'bar': 1, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'store': 6, 'establishment': 20, 'bakery': 3},
{'places': 20, 'cafe': 20, 'spa': 1, 'lodging': 1, 'bar': 2, 'restaurant': 14, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 8},
{'places': 20, 'cafe': 20, 'bar': 2, 'restaurant': 11, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 2, 'store': 5, 'night_club': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 7, 'restaurant': 1, 'bakery': 1},
{'places': 20, 'cafe': 20, 'bar': 5, 'lodging': 3, 'restaurant': 12, 'food': 20, 'store': 5, 'point_of_interest': 20, 'establishment': 20, 'movie_theater': 1, 'night_club': 1, 'tourist_attraction': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'store': 11, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 2, 'bakery': 5, 'art_gallery': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 5, 'store': 3, 'park': 1},
{'places': 20, 'cafe': 20, 'bar': 7, 'lodging': 5, 'restaurant': 10, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 3, 'spa': 1, 'parking': 1, 'gym': 1, 'health': 1, 'movie_theater': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'spa': 1, 'lodging': 3, 'restaurant': 6, 'food': 20, 'parking': 1, 'point_of_interest': 20, 'establishment': 20, 'gym': 1, 'health': 1, 'meal_takeaway': 1, 'store': 8, 'bakery': 1},
{'places': 20, 'cafe': 20, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'restaurant': 8, 'store': 7, 'bakery': 3},
{'places': 20, 'cafe': 20, 'bakery': 2, 'restaurant': 12, 'food': 20, 'store': 5, 'point_of_interest': 20, 'establishment': 20, 'book_store': 1, 'bar': 3, 'night_club': 1},
{'places': 20, 'cafe': 20, 'lodging': 4, 'restaurant': 5, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'gym': 1, 'health': 1, 'parking': 1, 'spa': 1, 'bar': 1, 'store': 5, 'bakery': 1},
{'places': 20, 'bar': 3, 'cafe': 20, 'lodging': 3, 'restaurant': 12, 'food': 20, 'point_of_interest': 20, 'store': 12, 'establishment': 20, 'movie_theater': 1, 'night_club': 1, 'bakery': 1, 'tourist_attraction': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'store': 8, 'point_of_interest': 20, 'establishment': 20, 'bakery': 5, 'restaurant': 10, 'bar': 3, 'lodging': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'bar': 3, 'lodging': 2, 'restaurant': 12, 'food': 20, 'store': 11, 'point_of_interest': 20, 'establishment': 20, 'tourist_attraction': 1, 'bakery': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 2, 'store': 6, 'bakery': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 9, 'home_goods_store': 1, 'restaurant': 2},
{'places': 20, 'cafe': 20, 'point_of_interest': 20, 'store': 2, 'food': 20, 'establishment': 20},
{'places': 20, 'cafe': 20, 'spa': 1, 'lodging': 1, 'bar': 2, 'restaurant': 11, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 7, 'night_club': 1, 'book_store': 1},
{'places': 20, 'cafe': 20, 'bar': 1, 'restaurant': 9, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 1, 'store': 4},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 10, 'store': 6, 'bakery': 1, 'night_club': 1, 'bar': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 8, 'home_goods_store': 1, 'restaurant': 2},
{'places': 20, 'cafe': 20, 'spa': 1, 'bar': 2, 'lodging': 1, 'restaurant': 11, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'bakery': 2, 'store': 6, 'book_store': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'bar': 2, 'restaurant': 13, 'food': 20, 'spa': 1, 'lodging': 1, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 8, 'night_club': 1},
{'places': 12, 'cafe': 12, 'point_of_interest': 12, 'food': 12, 'establishment': 12, 'bakery': 2, 'store': 2},
{'places': 20, 'bar': 7, 'cafe': 20, 'lodging': 4, 'store': 3, 'restaurant': 10, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'gym': 1, 'health': 1, 'movie_theater': 1, 'night_club': 1},
{'places': 20, 'restaurant': 6, 'cafe': 20, 'bar': 1, 'food': 20, 'store': 12, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3},
{'places': 20, 'bar': 2, 'cafe': 20, 'spa': 1, 'lodging': 1, 'restaurant': 14, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 8, 'night_club': 1},
{'places': 20, 'restaurant': 6, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 4, 'store': 8, 'bar': 1},
{'places': 20, 'cafe': 20, 'spa': 1, 'bar': 3, 'lodging': 1, 'restaurant': 12, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'bakery': 4, 'store': 8, 'book_store': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 2, 'store': 7, 'restaurant': 4, 'home_goods_store': 1},
{'places': 20, 'cafe': 20, 'store': 7, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 1, 'restaurant': 2, 'bar': 1},
{'places': 10, 'cafe': 10, 'food': 10, 'point_of_interest': 10, 'establishment': 10, 'bakery': 2, 'store': 2},
{'places': 20, 'cafe': 20, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'store': 13, 'restaurant': 4, 'bar': 1, 'meal_takeaway': 1, 'bakery': 3, 'meal_delivery': 1},
{'places': 8, 'restaurant': 2, 'cafe': 8, 'food': 8, 'point_of_interest': 8, 'establishment': 8, 'store': 1},
{'places': 20, 'cafe': 20, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'restaurant': 8, 'bar': 1, 'night_club': 1, 'store': 5, 'bakery': 1},
{'places': 8, 'locality': 1, 'political': 1, 'general_contractor': 1, 'point_of_interest': 7, 'establishment': 7, 'car_repair': 1, 'police': 1, 'park': 1},
{'places': 20, 'cafe': 20, 'restaurant': 7, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 9, 'bakery': 2, 'book_store': 1, 'movie_rental': 1, 'electronics_store': 1, 'home_goods_store': 1, 'bar': 1},
{'places': 20, 'cafe': 20, 'restaurant': 5, 'food': 20, 'store': 11, 'point_of_interest': 20, 'establishment': 20, 'bakery': 4, 'bar': 1},
{'places': 20, 'bar': 7, 'cafe': 20, 'lodging': 5, 'restaurant': 11, 'food': 20, 'point_of_interest': 20, 'store': 2, 'establishment': 20, 'gym': 1, 'health': 1, 'spa': 1, 'parking': 1, 'movie_theater': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'lodging': 3, 'store': 7, 'restaurant': 11, 'food': 20, 'bar': 5, 'point_of_interest': 20, 'establishment': 20, 'movie_theater': 1, 'night_club': 1, 'bakery': 2},
{'places': 20, 'cafe': 20, 'spa': 1, 'lodging': 1, 'bar': 2, 'restaurant': 12, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 8, 'night_club': 1, 'book_store': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 2, 'bar': 1, 'store': 1},
{'places': 4, 'cafe': 4, 'food': 4, 'point_of_interest': 4, 'establishment': 4, 'store': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 5, 'store': 2, 'bar': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'store': 7, 'establishment': 20, 'bakery': 1, 'restaurant': 2, 'bar': 1},
{'places': 11, 'cafe': 11, 'bakery': 1, 'restaurant': 4, 'food': 11, 'point_of_interest': 11, 'store': 1, 'establishment': 11, 'bar': 1, 'lodging': 1},
{'places': 20, 'cafe': 20, 'restaurant': 5, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'lodging': 1, 'store': 5, 'bar': 1},
{'places': 1, 'cafe': 1, 'food': 1, 'point_of_interest': 1, 'establishment': 1},
{'places': 20, 'cafe': 20, 'spa': 1, 'bar': 2, 'lodging': 1, 'restaurant': 12, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 8, 'night_club': 1, 'book_store': 1},
{'places': 20, 'parking': 1, 'cafe': 20, 'spa': 1, 'lodging': 1, 'restaurant': 5, 'point_of_interest': 20, 'food': 20, 'establishment': 20, 'store': 8, 'bakery': 1},
{'places': 20, 'cafe': 20, 'restaurant': 3, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 1, 'store': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'store': 6, 'point_of_interest': 20, 'establishment': 20, 'bar': 2, 'restaurant': 3, 'night_club': 1, 'bakery': 2, 'laundry': 1, 'lodging': 1, 'parking': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 1, 'store': 8, 'home_goods_store': 1},
{'places': 20, 'gas_station': 1, 'convenience_store': 1, 'bakery': 2, 'cafe': 20, 'car_repair': 1, 'food': 20, 'point_of_interest': 20, 'store': 2, 'establishment': 20, 'restaurant': 5},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'restaurant': 9, 'store': 6, 'liquor_store': 1, 'florist': 1},
{'places': 20, 'cafe': 20, 'bar': 2, 'spa': 1, 'lodging': 1, 'restaurant': 11, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 7, 'night_club': 1, 'book_store': 1},
{'places': 20, 'cafe': 20, 'bar': 7, 'restaurant': 9, 'lodging': 3, 'point_of_interest': 20, 'food': 20, 'store': 2, 'establishment': 20, 'movie_theater': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'store': 4, 'restaurant': 2, 'bakery': 1, 'meal_delivery': 1},
{'places': 20, 'cafe': 20, 'bar': 2, 'spa': 1, 'lodging': 1, 'restaurant': 11, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 7, 'book_store': 1, 'night_club': 1},
{'places': 20, 'cafe': 20, 'bar': 2, 'spa': 1, 'lodging': 1, 'restaurant': 14, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 8, 'night_club': 1},
{'places': 20, 'cafe': 20, 'bar': 2, 'spa': 1, 'lodging': 1, 'restaurant': 13, 'food': 20, 'point_of_interest': 20, 'establishment': 20, 'bakery': 3, 'store': 8, 'night_club': 1},
{'places': 20, 'cafe': 20, 'lodging': 3, 'restaurant': 8, 'bar': 7, 'point_of_interest': 20, 'store': 2, 'food': 20, 'establishment': 20, 'movie_theater': 1, 'night_club': 1}]

# %%
len(lst9)
# Out:
# 100

# %%
df=pd.DataFrame(lst9)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   places              100 non-null    int64
#  1   cafe                99 non-null     float64
#  2   bar                 67 non-null     float64
#  3   spa                 30 non-null     float64
#  4   lodging             44 non-null     float64
#  5   restaurant          94 non-null     float64
#  6   food                99 non-null     float64
#  7   point_of_interest   100 non-null    int64
#  8   establishment       100 non-null    int64
#  9   bakery              70 non-null     float64
#  10  store               98 non-null     float64
#  11  night_club          37 non-null     float64
#  12  book_store          15 non-null     float64
#  13  tourist_attraction  4 non-null      float64
#  14  florist             3 non-null      float64
# ...

# %%
df1=pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\CULTURAL VIEWER FINAL PROJECT\MONU.csv')

# %%
df1
# Out:
#                               name rating    reviews  \
# 0                    Mezquita Azul    4,7   (82.703)
# 1                       Gran Bazar    4,4  (117.603)
# 2            Bazar de las Especias    4,5  (138.987)
# 3             Mezquita de Suleiman    4,9   (43.378)
# 4      Hipódromo de Constantinopla    4,7   (26.368)
# ..                             ...    ...        ...
# 95             Rahmi M. Koç Museum    4,8   (20.887)
# 96  Museo de Arte Turco e Islámico    4,6    (3.461)
# 97              Palacio de Topkapi    4,7   (78.379)
# 98  Museo arqueológico de Estambul    4,6   (13.443)
# 99                     Pera Museum    4,6    (4.767)
#
#                                    description         descriptor
# 0         Famosa Mezquita Azul con 6 alminares           Mezquita
# 1     Laberinto de vistosos mercados cubiertos            Mercado
# 2     Mercado de especias y productos textiles            Mercado
# ...

# %%
complete_df= pd.merge(df1, df, left_index=True, right_index=True)

# %%
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 41 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                100 non-null    object
#  1   rating              100 non-null    object
#  2   reviews             100 non-null    object
#  3   description         100 non-null    object
#  4   descriptor          100 non-null    object
#  5   places              100 non-null    int64
#  6   cafe                99 non-null     float64
#  7   bar                 67 non-null     float64
#  8   spa                 30 non-null     float64
#  9   lodging             44 non-null     float64
#  10  restaurant          94 non-null     float64
#  11  food                99 non-null     float64
#  12  point_of_interest   100 non-null    int64
#  13  establishment       100 non-null    int64
#  14  bakery              70 non-null     float64
# ...

# %%
complete_df.to_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\CULTURAL VIEWER FINAL PROJECT\full_df.csv', sep=',', encoding='utf-8', index=False)
